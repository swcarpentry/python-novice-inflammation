# %% [markdown]
# # Recreating Starry Night using IPythonblocks

# %% [markdown]
# This exercise borrows heavily from Matt Davis' [exercise][1] but doesn't write it out to a file, and doesn't use functions that a python novice maybe hasn't seen yet. It requires Matt's [ipythonblocks][1], which you should already have installed, and the [Python Image Library][3](PIL), which you may not have installed. If you need to install PIL, at the command line type:
#
#     conda install pil
#
# [1]: https://github.com/jiffyclub/ipythonblocks
# [2]: https://github.com/jiffyclub/ipythonblocks
# [3]: http://effbot.org/imagingbook/pil-index.htm

# %%
from PIL import Image

# %% [markdown]
# First we need to read the image in.

# %%
im = Image.open('starry_night.jpg')

# %% [markdown]
# If we want to display the image in our notebook, we can use functions built into IPython itself to do so. Unfortunately, the name of the module that displays images in an IPython notebook and the one we've used to read the jpeg are the same: Image. So we'll import the one from IPython and give it another name (ipyIm).

# %%
im.load_djpeg
# Out:
# <bound method JpegImageFile.load_djpeg of <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x398 at 0x1044B0710>>

# %%
from IPython.core.display import Image as ipyIm
# ipyIm(filename='starry_night.jpg') 
ipyIm(filename=im.load_djpeg)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-e04ac03634db> in <module>()
#       1 from IPython.core.display import Image as ipyIm
#       2 # ipyIm(filename='starry_night.jpg')
# ----> 3 ipyIm(filename=im.load_djpeg)
#
# /Users/jeramiaory/anaconda/lib/python2.7/site-packages/IPython/core/display.pyc in __init__(self, data, url, filename, format, embed, width, height, retina)
#     612         """
#     613         if filename is not None:
# --> 614             ext = self._find_ext(filename)
#     615         elif url is not None:
#     616             ext = self._find_ext(url)
#
# /Users/jeramiaory/anaconda/lib/python2.7/site-packages/IPython/core/display.pyc in _find_ext(self, s)
#     700
#     701     def _find_ext(self, s):
# --> 702         return unicode_type(s.split('.')[-1].lower())
#     703
#     704
#
# ...

# %%
im.size
# Out:
# (500, 398)

# %%
im = im.resize((125, 100), Image.ANTIALIAS)

# %%
im.size
# Out:
# (125, 100)

# %%
from ipythonblocks import BlockGrid
grid = BlockGrid(125, 100, block_size=4, lines_on=False)

# %%
row = 0
column = 0

for pixel in im.getdata():
    grid[row,column]=pixel
    if column == 124:
        column = 0
        row = row + 1
    else:
        column = column + 1

# %%
grid
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks0b318830-eea2-46e3-a1a0-195dc3c170d3 td {border: 0px solid white;}</style><table id="blocks0b318830-eea2-46e3-a1a0-195dc3c170d3" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (121, 109, 84)" style="width: 4px; height: 4px;background-color: rgb(121, 109, 84);"></td><td title="Index: [0, 1]&#10;Color: (122, 115, 99)" style="width: 4px; height: 4px;background-color: rgb(122, 115, 99);"></td><td title="Index: [0, 2]&#10;Color: (117, 110, 96)" style="width: 4px; height: 4px;background-color: rgb(117, 110, 96);"></td><td title="Index: [0, 3]&#10;Color: (119, 111, 95)" style="width: 4px; height: 4px;background-color: rgb(119, 111, 95);"></td><td title="Index: [0, 4]&#10;Color: (89, 86, 79)" style="width: 4px; height: 4px;background-color: rgb(89, 86, 79);"></td><td title="Index: [0, 5]&#10;Color: (73, 78, 84)" style="width: 4px; height: 4px;background-
# ...

# %%
grid2 = BlockGrid(125, 100, block_size=4, lines_on=False)

row = 0
column = 0

for pixel in im.getdata():
    grid2[row,column].red = pixel[0]/50*50
    grid2[row,column].green = pixel[1]/50*50
    grid2[row,column].blue = pixel[2]/50*50
    if column == 124:
        column = 0
        row = row + 1
    else:
        column = column + 1

# %%
grid2
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksa34a11c1-87da-4325-bf26-2546673a2b2c td {border: 0px solid white;}</style><table id="blocksa34a11c1-87da-4325-bf26-2546673a2b2c" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (100, 100, 50)" style="width: 4px; height: 4px;background-color: rgb(100, 100, 50);"></td><td title="Index: [0, 1]&#10;Color: (100, 100, 50)" style="width: 4px; height: 4px;background-color: rgb(100, 100, 50);"></td><td title="Index: [0, 2]&#10;Color: (100, 100, 50)" style="width: 4px; height: 4px;background-color: rgb(100, 100, 50);"></td><td title="Index: [0, 3]&#10;Color: (100, 100, 50)" style="width: 4px; height: 4px;background-color: rgb(100, 100, 50);"></td><td title="Index: [0, 4]&#10;Color: (50, 50, 50)" style="width: 4px; height: 4px;background-color: rgb(50, 50, 50);"></td><td title="Index: [0, 5]&#10;Color: (50, 50, 50)" style="width: 4px; height: 4px;background-
# ...
